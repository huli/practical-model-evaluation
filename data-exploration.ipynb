# %% [markdown]
# ### Data Exploration

# %%
# !ls data
# Out:
# multiple_choice_responses.csv questions_only.csv
# other_text_responses.csv      survey_schema.csv

# %%
import pandas as pd

# %%
responses = pd.read_csv('data/multiple_choice_responses.csv', low_memory=False)
responses.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 510                        22-24
# 2                                 423                        40-44
# 3                                  83                        55-59
# 4                                 391                        40-44
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                    Male
# 2                                    Male
# 3                                  Female
# 4                                    Male
#
#                                        Q2_OTHER_TEXT  \
# 0  What is your gender? - Prefer to self-describe...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# ...

# %%
responses.describe()
# Out:
#        Time from Start to Finish (seconds)     Q1     Q2 Q2_OTHER_TEXT     Q3  \
# count                                19718  19718  19718         19718  19718
# unique                                4169     12      5            46     60
# top                                    450  25-29   Male            -1  India
# freq                                    42   4458  16138         19668   4786
#
#                      Q4              Q5 Q5_OTHER_TEXT              Q6     Q7  \
# count             19324           19108         19718           14003  13624
# unique                8              13           881               6      8
# top     Master’s degree  Data Scientist            -1  0-49 employees    20+
# freq               8549            4085         18384            4025   3178
#
#         ...            Q34_Part_4       Q34_Part_5        Q34_Part_6  \
# count   ...                  1853             1193               548
# ...

# %%
question_only = pd.read_csv('data/questions_only.csv')
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
#
#                                           Q3  \
# 0  In which country do you currently reside?
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
#
#                                                   Q6  \
# 0  What is the size of the company where you are ...
#
#                                                   Q7  \
# 0  Approximately how many individuals are respons...
#
#                                                   Q8  \
# 0  Does your current employer incorporate machine...
#
#                                                   Q9  ...  \
# ...

# %%
survey_schema = pd.read_csv('data/survey_schema.csv')
survey_schema.head()
# Out:
#   2019 Kaggle Machine Learning and Data Science Survey  \
# 0                                          Question:
# 1                                  # of Respondents:
# 2  Who was excluded? (0 = not excluded; 1 = exclu...
# 3    If What is your age (# years)? 0-17 Is Selected
# 4  If Select the title most similar to your curre...
#
#                             Q1  \
# 0  What is your age (# years)?
# 1                        19717
# 2                            0
# 3                            0
# 4                            0
#
#                                                  Q10  \
# 0  What is your current yearly compensation (appr...
# 1                                              12497
# 2                                                  0
# 3                                                  1
# 4                                                  1
#
#                                                  Q11  \
# 0  Approximately how much money have you spent on...
# ...

# %%
other_text_responses = pd.read_csv('data/other_text_responses.csv')
other_text_responses.head()
# Out:
#                                       Q12_OTHER_TEXT  \
# 0  Who/what are your favorite media sources that ...
# 1       "><script src=https://abels.xss.ht></script>
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       Q13_OTHER_TEXT  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       Q14_OTHER_TEXT  \
# 0  What is the primary tool that you use at work ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...
